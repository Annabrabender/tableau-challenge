# %%
# Import Dependencies
import os
import csv
import pandas as pd
from sqlalchemy import create_engine

# %%
# load and store dfs
citibike_2022_df = pd.concat(
    map(pd.read_csv, [
        'Resources/2022-data/JC-202201-citibike-tripdata.csv',
        'Resources/2022-data/JC-202202-citibike-tripdata.csv',
        'Resources/2022-data/JC-202203-citibike-tripdata.csv',
        'Resources/2022-data/JC-202204-citibike-tripdata.csv',
        'Resources/2022-data/JC-202205-citibike-tripdata.csv',
        'Resources/2022-data/JC-202206-citibike-tripdata.csv',
        'Resources/2022-data/JC-202207-citbike-tripdata.csv',
        'Resources/2022-data/JC-202208-citibike-tripdata.csv',
        'Resources/2022-data/JC-202209-citibike-tripdata.csv',
        'Resources/2022-data/JC-202210-citibike-tripdata.csv',
        'Resources/2022-data/JC-202211-citibike-tripdata.csv',
        'Resources/2022-data/JC-202212-citibike-tripdata.csv'
        ]), ignore_index=True)

output_data_2022 = "./Resources/citibike_2022.csv"

citibike_2022_df.info()
citibike_2022_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895485 entries, 0 to 895484
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             895485 non-null  object
#  1   rideable_type       895485 non-null  object
#  2   started_at          895485 non-null  object
#  3   ended_at            895485 non-null  object
#  4   start_station_name  895475 non-null  object
#  5   start_station_id    895475 non-null  object
#  6   end_station_name    892281 non-null  object
#  7   end_station_id      892281 non-null  object
#  8   start_lat           895485 non-null  float64
#  9   start_lng           895485 non-null  float64
#  10  end_lat             893515 non-null  float64
#  11  end_lng             893515 non-null  float64
#  12  member_casual       895485 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 88.8+ MB
# ...

# %%
# rename columns
citibike_2022_df = citibike_2022_df.rename(columns = {
    'ride_id': 'ride id',
    'rideable_type': 'ride type', 
    'started_at': 'start at', 
    'ended_at': 'end at',
    'start_station_name': 'start station name', 
    'start_station_id': 'start station id', 
    'end_station_name': 'end station name',
    'end_station_id': 'end station id', 
    'start_lat': 'start latitude', 
    'start_lng': 'start longitude', 
    'end_lat': 'end latitude', 
    'end_lng': 'end longitude',
    'member_casual': 'membership'
})
citibike_2022_df.head()
# Out:
#             ride id      ride type             start at               end at  \
# 0  CA5837152804D4B5  electric_bike  2022-01-26 18:50:39  2022-01-26 18:51:53
# 1  BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07  2022-01-28 13:20:23
# 2  7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13  2022-01-10 20:00:37
# 3  6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57  2022-01-26 07:55:22
# 4  E24954255BBDE32D  electric_bike  2022-01-13 18:44:46  2022-01-13 18:45:43
#
#      start station name start station id      end station name end station id  \
# 0  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
# 1      Essex Light Rail            JC038      Essex Light Rail          JC038
# 2      Essex Light Rail            JC038      Essex Light Rail          JC038
# 3  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
# 4  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
#
# ...

# %%
#export to csv
citibike_2022_df.to_csv("./Resources/citibike_2022.csv", index = False)

# %%
# load and store dfs
citibike_2023_df = pd.concat(
    map(pd.read_csv, [
        'Resources/2023-data/JC-202301-citibike-tripdata.csv',
        'Resources/2023-data/JC-202302-citibike-tripdata.csv',
        'Resources/2023-data/JC-202303-citibike-tripdata.csv',
        'Resources/2023-data/JC-202304-citibike-tripdata.csv',
        'Resources/2023-data/JC-202305-citibike-tripdata.csv',
        'Resources/2023-data/JC-202306-citibike-tripdata.csv',
        'Resources/2023-data/JC-202307-citibike-tripdata.csv',
        'Resources/2023-data/JC-202308-citibike-tripdata.csv',
        'Resources/2023-data/JC-202309-citibike-tripdata.csv',
        'Resources/2023-data/JC-202310-citibike-tripdata.csv',
        'Resources/2023-data/JC-202311-citibike-tripdata.csv',
        'Resources/2023-data/JC-202312-citibike-tripdata.csv'
        ]), ignore_index=True)
# output file path
output_data_2023 = "./Resources/citibike_2023.csv"
# #export to csv
# citibike_2021_df.to_csv("./Resources/citibike_2021.csv", index = False)

citibike_2023_df.info()
citibike_2023_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988851 entries, 0 to 988850
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             988851 non-null  object
#  1   rideable_type       988851 non-null  object
#  2   started_at          988851 non-null  object
#  3   ended_at            988851 non-null  object
#  4   start_station_name  988766 non-null  object
#  5   start_station_id    988766 non-null  object
#  6   end_station_name    985532 non-null  object
#  7   end_station_id      985532 non-null  object
#  8   start_lat           988851 non-null  float64
#  9   start_lng           988851 non-null  float64
#  10  end_lat             987897 non-null  float64
#  11  end_lng             987897 non-null  float64
#  12  member_casual       988851 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 98.1+ MB
# ...

# %%
citibike_2023_df = citibike_2023_df.rename(columns = {
    'ride_id': 'ride id',
    'rideable_type': 'ride type', 
    'started_at': 'start at', 
    'ended_at': 'end at',
    'start_station_name': 'start station name', 
    'start_station_id': 'start station id', 
    'end_station_name': 'end station name',
    'end_station_id': 'end station id', 
    'start_lat': 'start latitude', 
    'start_lng': 'start longitude', 
    'end_lat': 'end latitude', 
    'end_lng': 'end longitude',
    'member_casual': 'membership'
})
citibike_2023_df.head()
# Out:
#             ride id      ride type             start at               end at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start station name start station id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end station name end station id  start latitude  \
# ...

# %%
#export to csv
citibike_2023_df.to_csv("./Resources/citibike_2023.csv", index = False)

# %%
# combine 2022 and 2023 
citibike_combined_df = pd.concat(
    map(pd.read_csv, [
        './Resources/citibike_2022.csv',
        './Resources/citibike_2023.csv'
        ]), ignore_index=True)
# output file path
output_data_combined = "./Resources/citibike_combined.csv"

citibike_combined_df.info()
citibike_combined_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884336 entries, 0 to 1884335
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride id             object
#  1   ride type           object
#  2   start at            object
#  3   end at              object
#  4   start station name  object
#  5   start station id    object
#  6   end station name    object
#  7   end station id      object
#  8   start latitude      float64
#  9   start longitude     float64
#  10  end latitude        float64
#  11  end longitude       float64
#  12  membership          object
# dtypes: float64(4), object(9)
# memory usage: 186.9+ MB
#                   ride id      ride type             start at  \
# 0        CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1        BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2        7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# ...

# %%
#export to csv
citibike_combined_df.to_csv("./Resources/citibike_combined.csv", index = False)
